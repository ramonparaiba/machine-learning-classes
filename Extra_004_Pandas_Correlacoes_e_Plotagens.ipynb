# %% [markdown]
# <a href="https://colab.research.google.com/github/ramonparaiba/machine-learning-classes/blob/main/Extra_004_Pandas_Correlacoes_e_Plotagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets-colab/w3schools/data.csv')

# %%
#Correlação entre as colunas
#o valor das correlações varia de -1 a 1. 
#quanto mais próximos dos extremos, maior a correlação
#quanto mais próximo de zero, menor a correlação
#uma boa correlação começa a partir de 0.6 (ou -0.6)(pesquisar melhor os porques)
df.corr()
#Análise preliminar
#Duração e calorias, tiveram uma alta correlação (0.922717)
#pode-se inferir que, quanto maior a duração do exercício, 
#maior o número de calorias queimadas
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# - Análise preliminar
# ***
# - Boa Correlação - Duração e Calorias, tiveram uma boa correlação (0.922717)
#  - entende-se que quanto maior a duração do exercício maior o número de calorias queimadas
# - Correlação ruim - Duração e MaxPulse, tiveram uma correlação baixa (0.009403). Ou seja, não dá pra prever o pulso máximo, apenas observando a duração do exercício.

# %% [markdown]
# ***
# #Plotagem

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
plt.show()

# %% [markdown]
# Gráfico de dispersão

# %%
df.plot.scatter(x = 'Duration', y= 'Calories') #A boa correlação entre eles aparece no gráfico
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
df.plot.scatter(x = 'Duration', y= 'Maxpulse', xlabel ='Duração', ylabel = 'Pulso máximo') #A correlação ruim entre eles aparece no gráfico
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Duração', ylabel='Pulso máximo'>

# %% [markdown]
# Histograma

# %%
#analisando o histograma, vemos que houve mais de 100 treinos que duraram entre 50 e 60 minutos
df.hist(column='Duration')
# Out:
# array([[<Axes: title={'center': 'Duration'}>]], dtype=object)
